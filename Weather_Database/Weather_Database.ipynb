# %% [markdown]
# # Deliverable 1. Retrieve Weather Data.
# ---
# 1. Create a folder called `Weather_Database` to save all the files related with this deliverable.
#
# 2. Save the `Weather_Database_starter_code.ipynb` starter code to the `Weather_Database` folder and rename it as `Weather_Database.ipynb`.
#
# 3. Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.
#
# 4. Use the `citipy` module to get the nearest city for each latitude and longitude combination.
#
# 5. Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key; also, it's critical to avoid publishing your API key on your GitHub repository.
#
# 6. Retrieve the following information from the API call:
#
#     * Latitude and longitude
#
#     * Maximum temperature
#
#     * Percent humidity
#
#     * Percent cloudiness
#
#     * Wind speed
#
#     * Weather description (for example, clouds, fog, light rain, clear sky)
#
# 7. Add the weather data to a new DataFrame.
#
# 8. Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.
# ---

# %%
# Import initial libraries
import numpy as np
import pandas as pd
from citipy import citipy
import time
import requests
from config import weather_api_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []
# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 739

# %%
print(cities)
# Out:
# ['aginskoye', 'taolanaro', 'kutum', 'valdivia', 'smoky lake', 'butaritari', 'vale da amoreira', 'balad', 'ushuaia', 'jamestown', 'tselina', 'tomohon', 'jalu', 'rikitea', 'los llanos de aridane', 'tome-acu', 'lagoa', 'itarema', 'kapaa', 'moerai', 'faanui', 'barrow', 'grand gaube', 'dikson', 'illoqqortoormiut', 'hobart', 'vaini', 'klaksvik', 'severnoye', 'charters towers', 'hithadhoo', 'punta arenas', 'ilulissat', 'bredasdorp', 'avarua', 'aklavik', 'hovd', 'norman wells', 'clyde river', 'ahuimanu', 'hermanus', 'vylok', 'fairbanks', 'sorland', 'luderitz', 'leh', 'albany', 'dingle', 'carnarvon', 'barra', 'new norfolk', 'kontagora', 'vila franca do campo', 'maragogi', 'ampanihy', 'bluff', 'kudahuvadhoo', 'rungata', 'pangnirtung', 'talnakh', 'yellowknife', 'bolu', 'birjand', 'immokalee', 'tepu', 'taunggyi', 'valenca', 'sitka', 'qaanaaq', 'geraldton', 'amapa', 'nikolskoye', 'praia da vitoria', 'upernavik', 'la mana', 'karratha', 'minot', 'nome', 'mataura', 'phan rang', 'laguna', 'wundanyi', 'oga', 'bambous virieux', 'san quintin', 'souillac', 'east london', 'ketchikan', 'nautla', 'sampit', 'lieksa', 'elko', 'hilo', 'ayagoz', 'saint george', 'blairmore', 'namibe', 'ancud', 'saint anthony', 'gisborne', 'joacaba', 'ardmore', 'atuona', 'polson', 'airai', 'arraial do cabo', 'mulchen', 'cauquenes', 'kodiak', 'severo-kurilsk', 'port lincoln', 'jorasti', 'dicabisagan', 'hvammstangi', 'moanda', 'tuktoyaktuk', 'kasungu', 'jibuti', 'tuatapere', 'zhigansk', 'solnechnyy', 'puerto ayora', 'busselton', 'nizhneyansk', 'grand river south east', 'mouzakion', 'hami', 'asau', 'shelburne', 'hilton head island', 'maltahohe', 'saskylakh', 'lompoc', 'talaya', 'bathsheba', 'lebu', 'thompson', 'somerset', 'nantucket', 'altay', 'mys shmidta', 'krasnovishersk', 'goderich', 'samalaeulu', 'deputatskiy', 'erenhot', 'torbay', 'poum', 'belushya guba', 'olafsvik', 'ribeira grande', 'banda aceh', 'sohag', 'taoudenni', 'georgetown', 'staraya toropa', 'tarija', 'masuguru', 'birin', 'yarada', 'cidreira', 'amderma', 'kavieng', 'camacha', 'valleyview', 'port elizabeth', 'louisbourg', 'grimshaw', 'vaitupu', 'samal', 'gaoua', 'nago', 'cape town', 'ercis', 'port alfred', 'kushmurun', 'miri', 'lorengau', 'mahebourg', 'victoria', 'chapleau', 'alofi', 'belaya gora', 'waipawa', 'isangel', 'cap malheureux', 'kisangani', 'tual', 'ponta do sol', 'iqaluit', 'mar del plata', 'toliary', 'castro', 'camocim', 'salalah', 'mujiayingzi', 'trincomalee', 'san cristobal', 'broome', 'vestmannaeyjar', 'marsa matruh', 'udachnyy', 'umm kaddadah', 'lengshuitan', 'nuuk', 'santa rosa', 'la paz', 'acajutla', 'savonlinna', 'saldanha', 'dauphin', 'sur', 'nanortalik', 'mitu', 'marsabit', 'chuy', 'necochea', 'mantua', 'uzhur', 'lasa', 'igarka', 'kabinda', 'tir pol', 'sofiysk', 'la ronge', 'kahului', 'ostrovnoy', 'porbandar', 'ahipara', 'zhigalovo', 'berberati', 'ambunti', 'atasu', 'kenai', 'ibra', 'dabat', 'south lake tahoe', 'vila velha', 'sentyabrskiy', 'umea', 'balabac', 'axim', 'rock falls', 'tigil', 'morondava', 'port hardy', 'kaitangata', 'lata', 'port hedland', 'yulara', 'tasiilaq', 'vardo', 'omboue', 'khairagarh', 'khatanga', 'wuhan', 'doctor pedro p. pena', 'kauhajoki', 'ugoofaaru', 'margate', 'san policarpo', 'barentsburg', 'ara', 'lagos', 'san javier', 'hay river', 'longyearbyen', 'guerrero negro', 'saint-pierre', 'bonthe', 'divnoye', 'nevers', 'monte alegre', 'leningradskiy', 'pallasovka', 'seoul', 'itarantim', 'brae', 'satitoa', 'pochutla', 'imeni poliny osipenko', 'sarkand', 'tumannyy', 'sakaiminato', 'broken hill', 'macusani', 'rio gallegos', 'ewa beach', 'wattens', 'killarney', 'carinhanha', 'richards bay', 'ourem', 'oranjemund', 'opochka', 'fallon', 'kemijarvi', 'puunsi', 'chokurdakh', 'northport', 'jinchang', 'caconda', 'yumen', 'boa vista', 'bethel', 'eenhana', 'upata', 'kaeo', 'santa cruz', 'akyab', 'saint-philippe', 'russellville', 'ngunguru', 'vao', 'ulladulla', 'seymchan', 'umzimvubu', 'tatahuicapan', 'bontang', 'luorong', 'kuah', 'coihaique', 'savannah bight', 'nouadhibou', 'digby' ...

# %%
# Starting URL for Weather Map API Call.
url = "https://api.openweathermap.org/data/2.5/weather?units=IMPERIAL&appid=" + weather_api_key

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in our list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count.
    record_count += 1
    
    # Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | aginskoye
# Processing Record 2 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 3 of Set 1 | kutum
# Processing Record 4 of Set 1 | valdivia
# Processing Record 5 of Set 1 | smoky lake
# Processing Record 6 of Set 1 | butaritari
# Processing Record 7 of Set 1 | vale da amoreira
# Processing Record 8 of Set 1 | balad
# Processing Record 9 of Set 1 | ushuaia
# Processing Record 10 of Set 1 | jamestown
# Processing Record 11 of Set 1 | tselina
# Processing Record 12 of Set 1 | tomohon
# Processing Record 13 of Set 1 | jalu
# Processing Record 14 of Set 1 | rikitea
# Processing Record 15 of Set 1 | los llanos de aridane
# Processing Record 16 of Set 1 | tome-acu
# City not found. Skipping...
# Processing Record 17 of Set 1 | lagoa
# Processing Record 18 of Set 1 | itarema
# Processing Record 19 of Set 1 | kapaa
# Processing Record 20 of Set 1 | moerai
# Processing Record 21 of Set 1 | faanui
# Processing Record 22 of Set 1 | barrow
# Processing Record 23 of Set 1 | grand gaube
# Processing Record 24 of Set 1 | dikson
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | hobart
# Processing Record 27 of Set 1 | vaini
# Processing Record 28 of Set 1 | klaksvik
# Processing Record 29 of Set 1 | severnoye
# Processing Record 30 of Set 1 | charters towers
# Processing Record 31 of Set 1 | hithadhoo
# Processing Record 32 of Set 1 | punta arenas
# Processing Record 33 of Set 1 | ilulissat
# Processing Record 34 of Set 1 | bredasdorp
# Processing Record 35 of Set 1 | avarua
# Processing Record 36 of Set 1 | aklavik
# Processing Record 37 of Set 1 | hovd
# Processing Record 38 of Set 1 | norman wells
# Processing Record 39 of Set 1 | clyde river
# Processing Record 40 of Set 1 | ahuimanu
# Processing Record 41 of Set 1 | hermanus
# Processing Record 42 of Set 1 | vylok
# Processing Record 43 of Set 1 | fairbanks
# Processing Record 44 of Set 1 | sorland
# Processing Record 45 of Set 1 | luderitz
# Processing Record 46 of Set 1 | leh
# Processing Record 47 of Set 1 | albany
# Processing Record 48 of Set 1 | dingle
# Processing Record 49 of Set 1 | carnarvon
# Processing Record 50 of Set 1 | barra
# Processing Record 1 of Set 2 | new norfolk
# Processing Record 2 of Set 2 | kontagora
# Processing Record 3 of Set 2 | vila franca do campo
# Processing Record 4 of Set 2 | maragogi
# Processing Record 5 of Set 2 | ampanihy
# Processing Record 6 of Set 2 | bluff
# Processing Record 7 of Set 2 | kudahuvadhoo
# Processing Record 8 of Set 2 | rungata
# City not found. Skipping...
# Processing Record 9 of Set 2 | pangnirtung
# Processing Record 10 of Set 2 | talnakh
# Processing Record 11 of Set 2 | yellowknife
# Processing Record 12 of Set 2 | bolu
# Processing Record 13 of Set 2 | birjand
# Processing Record 14 of Set 2 | immokalee
# Processing Record 15 of Set 2 | tepu
# Processing Record 16 of Set 2 | taunggyi
# Processing Record 17 of Set 2 | valenca
# Processing Record 18 of Set 2 | sitka
# Processing Record 19 of Set 2 | qaanaaq
# Processing Record 20 of Set 2 | geraldton
# Processing Record 21 of Set 2 | amapa
# Processing Record 22 of Set 2 | nikolskoye
# Processing Record 23 of Set 2 | praia da vitoria
# Processing Record 24 of Set 2 | upernavik
# Processing Record 25 of Set 2 | la mana
# Processing Record 26 of Set 2 | karratha
# Processing Record 27 of Set 2 | minot
# Processing Record 28 of Set 2 | nome
# Processing Record 29 of Set 2 | mataura
# Processing Record 30 of Set 2 | phan rang
# City not found. Skipping...
# Processing Record 31 of Set 2 | laguna
# Processing Record 32 of Set 2 | wundanyi
# Processing Record 33 of Set 2 | oga
# Processing Record 34 of Set 2 | bambous virieux
# Processing Record 35 of Set 2 | san quintin
# Processing Record 36 of Set 2 | souillac
# Processing Record 37 of Set 2 | east london
# Processing Record 38 of Set 2 | ketchikan
# Processing Record 39 of Set 2 | nautla
# Processing Record 40 of Set 2 | sampit
# Processing Record 41 of Set 2 | lieksa
# Processing Record 42 of Set 2 | elko
# Processing Record 43 of Set 2 | hilo
# Processing Record 44 of Set 2 | ayagoz
# Processing Record 45 of Set 2 | saint george
# Processing Record 46 of Set 2 | blairmore
# Processing Record 47 of Set 2 | namibe
# Processing Record 48 of Set 2 | ancud
# Processing Record 49 of Set 2 | saint anthony
# Processing Record 50 of Set 2 | gisborne
# Processing Record 1 of Set 3 | joacaba
# Processing Record 2 of Set 3 | ardmore
# Processing Record 3 of Set 3 | atuona
# Processing Record 4 of Set 3 | polson
# Processing Record 5 of Set 3 | airai
# Processing Record 6 of Set 3 | arraial do cabo
# Processing Record 7 of Set 3 | mulchen
# Processing Record 8 of Set 3 | cauquenes
# Processing Record 9 of Set 3 | kodiak
# Processing Record 10 of Set 3 | severo-kurilsk
# Processing Record 11 of Set 3 | port lincoln
# Processing Record 12 of Set 3 | jorasti
# Processing Record 13 of Set 3 | dicabisagan
# Processing Record 14 of Set 3 | hvammstangi
# City not found. Skipping...
# Processing Record 15 of Set 3 | moanda
# Processing Record 16 of Set 3 | tuktoyaktuk
# Processing Record 17 of Set 3 | kasungu
# Processing Record 18 of Set 3 | jibuti
# Processing Record 19 of Set 3 | tuatapere
# Processing Record 20 of Set 3 | zhigansk
# Processing Record 21 of Set 3 | solnechnyy
# Processing Record 22 of Set 3 | puerto ayora
# Processing Record 23 of Set 3 | busselton
# Processing Record 24 of Set 3 | nizhneyansk
# City not found. Skipping...
# Processing Record 25 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 26 of Set 3 | mouzakion
# City not found. Skipping...
# Processing Record 27 of Set 3 | hami
# Processing Record 28 of Set 3 | asau
# Processing Record 29 of Set 3 | shelburne
# Processing Record 30 of Set 3 | hilton head island
# Processing Record 31 of Set 3 | maltahohe
# Processing Record 32 of Set 3 | saskylakh
# Processing Record 33 of Set 3 | lompoc
# Processing Record 34 of Set 3 | talaya
# Processing Record 35 of Set 3 | bathsheba
# Processing Record 36 of Set 3 | lebu
# Processing Record 37 of Set 3 | thompson
# Processing Record 38 of Set 3 | somerset
# Processing Record 39 of Set 3 | nantucket
# Processing Record 40 of Set 3 | altay
# Processing Record 41 of Set 3 | mys shmidta
# City not found. Skipping...
# Processing Record 42 of Set 3 | krasnovishersk
# Processing Record 43 of Set 3 | goderich
# Processing Record 44 of Set 3 | samalaeulu
# City not found. Skipping...
# Processing Record 45 of Set 3 | deputatskiy
# Processing Record 46 of Set 3 | erenhot
# Processing Record 47 of Set 3 | torbay
# Processing Record 48 of Set 3 | poum
# Processing Record 49 of Set 3 | belushya guba
# City not found. Skipping...
# Processing Record 50 of Set 3 | olafsvik
# Processing Record 1 of Set 4 | ribeira grande
# Processing Record 2 of Set 4 | banda aceh
# Processing Record 3 of Set 4 | sohag
# Processing Record 4 of Set 4 | taoudenni
# Processing Record 5 of Set 4 | georgetown
# Processing Record 6 of Set 4 | staraya toropa
# Processing Record 7 of Set 4 | tarija
# Processing Record 8 of Set 4 | masuguru
# Processing Record 9 of Set 4 | birin
# Processing Record 10 of Set 4 | yarada
# Processing Record 11 of Set 4 | cidreira
# Processing Record 12 of Set 4 | amderma
# City not found. Skipping...
# Processing Record 13 of Set 4 | kavieng
# Processing Record 14 of Set 4 | camacha
# Processing Record 15 of Set 4 | valleyview
# Processing Record 16 of Set 4 | port elizabeth
# Processing Record 17 of Set 4 | louisbourg
# City not found. Skipping...
# Processing Record 18 of Set 4 | grimshaw
# Processing Record 19 of Set 4 | vaitupu
# City not found. Skipping...
# Processing Record 20 of Set 4 | samal
# Processing Record 21 of Set 4 | gaoua
# Processing Record 22 of Set 4 | nago
# Processing Record 23 of Set 4 | cape town
# Processing Record 24 of Set 4 | ercis
# Processing Record 25 of Set 4 | port alfred
# Processing Record 26 of Set 4 | kushmurun
# Processing Record 27 of Set 4 | miri
# Processing Record 28 of Set 4 | lorengau
# Processing Record 29 of Set 4 | mahebourg
# Processing Record 30 of Set 4 | victoria
# Processing Record 31 of Set 4 | chapleau
# Processing Record 32 of Set 4 | alofi
# Processing Record 33 of Set 4 | belaya gora
# Processing Record 34 of Set 4 | waipawa
# Processing Record 35 of Set 4 | isangel
# Processing Record 36 of Set 4 | cap malheureux
# Processing Record 37 of Set 4 | kisangani
# Processing Record 38 of Set 4 | tual
# Processing Record 39 of Set 4 | ponta do sol
# Processing Record 40 of Set 4 | iqaluit
# Processing Record 41 of Set 4 | mar del plata
# Processing Record 42 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 43 of Set 4 | castro
# Processing Record 44 of Set 4 | camocim
# Processing Record 45 of Set 4 | salalah
# Processing Record 46 of Set 4 | mujiayingzi
# Processing Record 47 of Set 4 | trincomalee
# Processing Record 48 of Set 4 | san cristobal
# Processing Record 49 of Set 4 | broome
# Processing Record 50 of Set 4 | vestmannaeyjar
# Processing Record 1 of Set 5 | marsa matruh
# Processing Record 2 of Set 5 | udachnyy
# Processing Record 3 of Set 5 | umm kaddadah
# Processing Record 4 of Set 5 | lengshuitan
# Processing Record 5 of Set 5 | nuuk
# Processing Record 6 of Set 5 | santa rosa
# Processing Record 7 of Set 5 | la paz
# Processing Record 8 of Set 5 | acajutla
# Processing Record 9 of Set 5 | savonlinna
# Processing Record 10 of Set 5 | saldanha
# Processing Record 11 of Set 5 | dauphin
# Processing Record 12 of Set 5 | sur
# Processing Record 13 of Set 5 | nanortalik
# Processing Record 14 of Set 5 | mitu
# Processing Record 15 of Set 5 | marsabit
# Processing Record 16 of Set 5 | chuy
# Processing Record 17 of Set 5 | necochea
# Processing Record 18 of Set 5 | mantua
# Processing Record 19 of Set 5 | uzhur
# Processing Record 20 of Set 5 | lasa
# Processing Record 21 of Set 5 | igarka
# Processing Record 22 of Set 5 | kabinda
# Processing Record 23 of Set 5 | tir pol
# City not found. Skipping...
# Processing Record 24 of Set 5 | sofiysk
# City not found. Skipping...
# Processing Record 25 of Set 5 | la ronge
# Processing Record 26 of Set 5 | kahului
# Processing Record 27 of Set 5 | ostrovnoy
# Processing Record 28 of Set 5 | porbandar
# Processing Record 29 of Set 5 | ahipara
# Processing Record 30 of Set 5 | zhigalovo
# Processing Record 31 of Set 5 | berberati
# Processing Record 32 of Set 5 | ambunti
# Processing Record 33 of Set 5 | atasu
# Processing Record 34 of Set 5 | kenai
# Processing Record 35 of Set 5 | ibra
# Processing Record 36 of Set 5 | dabat
# Processing Record 37 of Set 5 | south lake tahoe
# Processing Record 38 of Set 5 | vila velha
# Processing Record 39 of Set 5 | sentyabrskiy
# City not found. Skipping...
# Processing Record 40 of Set 5 | umea
# Processing Record 41 of Set 5 | balabac
# Processing Record 42 of Set 5 | axim
# Processing Record 43 of Set 5 | rock falls
# Processing Record 44 of Set 5 | tigil
# Processing Record 45 of Set 5 | morondava
# Processing Record 46 of Set 5 | port hardy
# Processing Record 47 of Set 5 | kaitangata
# Processing Record 48 of Set 5 | lata
# Processing Record 49 of Set 5 | port hedland
# Processing Record 50 of Set 5 | yulara
# Processing Record 1 of Set 6 | tasiilaq
# Processing Record 2 of Set 6 | vardo
# Processing Record 3 of Set 6 | omboue
# Processing Record 4 of Set 6 | khairagarh
# Processing Record 5 of Set 6 | khatanga
# Processing Record 6 of Set 6 | wuhan
# Processing Record 7 of Set 6 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 8 of Set 6 | kauhajoki
# Processing Record 9 of Set 6 | ugoofaaru
# Processing Record 10 of Set 6 | margate
# Processing Record 11 of Set 6 | san policarpo
# Processing Record 12 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 13 of Set 6 | ara
# Processing Record 14 of Set 6 | lagos
# Processing Record 15 of Set 6 | san javier
# Processing Record 16 of Set 6 | hay river
# Processing Record 17 of Set 6 | longyearbyen
# Processing Record 18 of Set 6 | guerrero negro
# Processing Record 19 of Set 6 | saint-pierre
# Processing Record 20 of Set 6 | bonthe
# Processing Record 21 of Set 6 | divnoye
# Processing Record 22 of Set 6 | nevers
# Processing Record 23 of Set 6 | monte alegre
# Processing Record 24 of Set 6 | leningradskiy
# Processing Record 25 of Set 6 | pallasovka
# Processing Record 26 of Set 6 | seoul
# Processing Record 27 of Set 6 | itarantim
# Processing Record 28 of Set 6 | brae
# Processing Record 29 of Set 6 | satitoa
# City not found. Skipping...
# Processing Record 30 of Set 6 | pochutla
# Processing Record 31 of Set 6 | imeni poliny osipenko
# Processing Record 32 of Set 6 | sarkand
# Processing Record 33 of Set 6 | tumannyy
# City not found. Skipping...
# Processing Record 34 of Set 6 | sakaiminato
# Processing Record 35 of Set 6 | broken hill
# Processing Record 36 of Set 6 | macusani
# Processing Record 37 of Set 6 | rio gallegos
# Processing Record 38 of Set 6 | ewa beach
# Processing Record 39 of Set 6 | wattens
# Processing Record 40 of Set 6 | killarney
# Processing Record 41 of Set 6 | carinhanha
# Processing Record 42 of Set 6 | richards bay
# Processing Record 43 of Set 6 | ourem
# Processing Record 44 of Set 6 | oranjemund
# Processing Record 45 of Set 6 | opochka
# Processing Record 46 of Set 6 | fallon
# Processing Record 47 of Set 6 | kemijarvi
# Processing Record 48 of Set 6 | puunsi
# City not found. Skipping...
# Processing Record 49 of Set 6 | chokurdakh
# Processing Record 50 of Set 6 | northport
# Processing Record 1 of Set 7 | jinchang
# Processing Record 2 of Set 7 | caconda
# Processing Record 3 of Set 7 | yumen
# Processing Record 4 of Set 7 | boa vista
# Processing Record 5 of Set 7 | bethel
# Processing Record 6 of Set 7 | eenhana
# Processing Record 7 of Set 7 | upata
# Processing Record 8 of Set 7 | kaeo
# Processing Record 9 of Set 7 | santa cruz
# Processing Record 10 of Set 7 | akyab
# Processing Record 11 of Set 7 | saint-philippe
# Processing Record 12 of Set 7 | russellville
# Processing Record 13 of Set 7 | ngunguru
# Processing Record 14 of Set 7 | vao
# Processing Record 15 of Set 7 | ulladulla
# Processing Record 16 of Set 7 | seymchan
# Processing Record 17 of Set 7 | umzimvubu
# City not found. Skipping...
# Processing Record 18 of Set 7 | tatahuicapan
# Processing Record 19 of Set 7 | bontang
# Processing Record 20 of Set 7 | luorong
# Processing Record 21 of Set 7 | kuah
# Processing Record 22 of Set 7 | coihaique
# Processing Record 23 of Set 7 | savannah bight
# Processing Record 24 of Set 7 | nouadhibou
# Processing Record 25 of Set 7 | digby
# Processing Record 26 of Set 7 | tautira
# Processing Record 27 of Set 7 | kargapolye
# City not found. Skipping...
# Processing Record 28 of Set 7 | mitsamiouli
# Processing Record 29 of Set 7 | brokopondo
# Processing Record 30 of Set 7 | manbij
# Processing Record 31 of Set 7 | wieliczka
# Processing Record 32 of Set 7 | luanda
# Processing Record 33 of Set 7 | saleaula
# City not found. Skipping...
# Processing Record 34 of Set 7 | henties bay
# Processing Record 35 of Set 7 | tazovskiy
# Processing Record 36 of Set 7 | davila
# Processing Record 37 of Set 7 | shimanovsk
# Processing Record 38 of Set 7 | caravelas
# Processing Record 39 of Set 7 | tiksi
# Processing Record 40 of Set 7 | sydney
# Processing Record 41 of Set 7 | kyle of lochalsh
# City not found. Skipping...
# Processing Record 42 of Set 7 | fare
# Processing Record 43 of Set 7 | fortuna
# Processing Record 44 of Set 7 | sayat
# Processing Record 45 of Set 7 | nanchital
# Processing Record 46 of Set 7 | ngukurr
# City not found. Skipping...
# Processing Record 47 of Set 7 | padang
# Processing Record 48 of Set 7 | mezen
# Processing Record 49 of Set 7 | skjervoy
# Processing Record 50 of Set 7 | yakima
# Processing Record 1 of Set 8 | bargal
# City not found. Skipping...
# Processing Record 2 of Set 8 | svetlaya
# Processing Record 3 of Set 8 | nucet
# Processing Record 4 of Set 8 | kimbe
# Processing Record 5 of Set 8 | warqla
# City not found. Skipping...
# Processing Record 6 of Set 8 | yurty
# Processing Record 7 of Set 8 | pokrovka
# Processing Record 8 of Set 8 | labutta
# City not found. Skipping...
# Processing Record 9 of Set 8 | khonuu
# City not found. Skipping...
# Processing Record 10 of Set 8 | lewistown
# Processing Record 11 of Set 8 | beloha
# Processing Record 12 of Set 8 | sayyan
# Processing Record 13 of Set 8 | peruibe
# Processing Record 14 of Set 8 | takaka
# Processing Record 15 of Set 8 | saint-joseph
# Processing Record 16 of Set 8 | ternate
# Processing Record 17 of Set 8 | rockport
# Processing Record 18 of Set 8 | santa rosalia
# Processing Record 19 of Set 8 | buala
# Processing Record 20 of Set 8 | mananjary
# Processing Record 21 of Set 8 | elizabeth city
# Processing Record 22 of Set 8 | holland
# Processing Record 23 of Set 8 | taburi
# City not found. Skipping...
# Processing Record 24 of Set 8 | yakeshi
# Processing Record 25 of Set 8 | truro
# Processing Record 26 of Set 8 | haripur
# Processing Record 27 of Set 8 | mushie
# Processing Record 28 of Set 8 | perelyub
# Processing Record 29 of Set 8 | adeje
# Processing Record 30 of Set 8 | fairmont
# Processing Record 31 of Set 8 | morrope
# Processing Record 32 of Set 8 | ulaangom
# Processing Record 33 of Set 8 | kentau
# Processing Record 34 of Set 8 | kieta
# Processing Record 35 of Set 8 | sioux lookout
# Processing Record 36 of Set 8 | vydrino
# Processing Record 37 of Set 8 | xiangfan
# Processing Record 38 of Set 8 | bengkulu
# Processing Record 39 of Set 8 | hervey bay
# Processing Record 40 of Set 8 | mount gambier
# Processing Record 41 of Set 8 | grand centre
# City not found. Skipping...
# Processing Record 42 of Set 8 | sambava
# Processing Record 43 of Set 8 | sao filipe
# Processing Record 44 of Set 8 | vanderhoof
# Processing Record 45 of Set 8 | vostok
# Processing Record 46 of Set 8 | chiajna
# Processing Record 47 of Set 8 | bara
# Processing Record 48 of Set 8 | ratnagiri
# Processing Record 49 of Set 8 | totness
# Processing Record 50 of Set 8 | morehead
# Processing Record 1 of Set 9 | alvorada
# Processing Record 2 of Set 9 | bonfim
# Processing Record 3 of Set 9 | tsihombe
# City not found. Skipping...
# Processing Record 4 of Set 9 | san joaquin
# Processing Record 5 of Set 9 | edson
# Processing Record 6 of Set 9 | katsuura
# Processing Record 7 of Set 9 | kamenka
# Processing Record 8 of Set 9 | amarillo
# Processing Record 9 of Set 9 | maghama
# City not found. Skipping...
# Processing Record 10 of Set 9 | shitanjing
# Processing Record 11 of Set 9 | cockburn town
# Processing Record 12 of Set 9 | inverness
# Processing Record 13 of Set 9 | san patricio
# Processing Record 14 of Set 9 | paita
# Processing Record 15 of Set 9 | khani
# Processing Record 16 of Set 9 | samusu
# City not found. Skipping...
# Processing Record 17 of Set 9 | taltal
# Processing Record 18 of Set 9 | marawi
# Processing Record 19 of Set 9 | roald
# Processing Record 20 of Set 9 | cabo san lucas
# Processing Record 21 of Set 9 | mayo
# Processing Record 22 of Set 9 | collie
# Processing Record 23 of Set 9 | matagami
# Processing Record 24 of Set 9 | bonavista
# Processing Record 25 of Set 9 | woodstock
# Processing Record 26 of Set 9 | haines junction
# Processing Record 27 of Set 9 | zhezkazgan
# Processing Record 28 of Set 9 | rafai
# Processing Record 29 of Set 9 | bilma
# Processing Record 30 of Set 9 | cayenne
# Processing Record 31 of Set 9 | lokosovo
# Processing Record 32 of Set 9 | provideniya
# Processing Record 33 of Set 9 | katima mulilo
# Processing Record 34 of Set 9 | viedma
# Processing Record 35 of Set 9 | amboasary
# Processing Record 36 of Set 9 | potsdam
# Processing Record 37 of Set 9 | kushiro
# Processing Record 38 of Set 9 | half moon bay
# Processing Record 39 of Set 9 | cherskiy
# Processing Record 40 of Set 9 | marcona
# City not found. Skipping...
# Processing Record 41 of Set 9 | peravurani
# Processing Record 42 of Set 9 | santa eulalia del rio
# City not found. Skipping...
# Processing Record 43 of Set 9 | havelock
# Processing Record 44 of Set 9 | payo
# Processing Record 45 of Set 9 | douglas
# Processing Record 46 of Set 9 | okhotsk
# Processing Record 47 of Set 9 | willowmore
# Processing Record 48 of Set 9 | allanmyo
# City not found. Skipping...
# Processing Record 49 of Set 9 | prokuplje
# Processing Record 50 of Set 9 | tarudant
# City not found. Skipping...
# Processing Record 1 of Set 10 | maloy
# Processing Record 2 of Set 10 | colesberg
# Processing Record 3 of Set 10 | micheweni
# Processing Record 4 of Set 10 | constitucion
# Processing Record 5 of Set 10 | meadow lake
# Processing Record 6 of Set 10 | sao joao da barra
# Processing Record 7 of Set 10 | anadyr
# Processing Record 8 of Set 10 | pechora
# Processing Record 9 of Set 10 | esperance
# Processing Record 10 of Set 10 | arandis
# Processing Record 11 of Set 10 | sheboygan
# Processing Record 12 of Set 10 | attawapiskat
# City not found. Skipping...
# Processing Record 13 of Set 10 | chagda
# City not found. Skipping...
# Processing Record 14 of Set 10 | lima
# Processing Record 15 of Set 10 | srednekolymsk
# Processing Record 16 of Set 10 | shibarghan
# City not found. Skipping...
# Processing Record 17 of Set 10 | russell
# Processing Record 18 of Set 10 | bereda
# Processing Record 19 of Set 10 | araouane
# Processing Record 20 of Set 10 | okha
# Processing Record 21 of Set 10 | astipalaia
# City not found. Skipping...
# Processing Record 22 of Set 10 | grindavik
# Processing Record 23 of Set 10 | saquisili
# Processing Record 24 of Set 10 | turukhansk
# Processing Record 25 of Set 10 | lensk
# Processing Record 26 of Set 10 | gat
# Processing Record 27 of Set 10 | yar-sale
# Processing Record 28 of Set 10 | tsumeb
# Processing Record 29 of Set 10 | andenes
# Processing Record 30 of Set 10 | krasnoselkup
# Processing Record 31 of Set 10 | honiara
# Processing Record 32 of Set 10 | erzin
# Processing Record 33 of Set 10 | bolungarvik
# City not found. Skipping...
# Processing Record 34 of Set 10 | jardim
# Processing Record 35 of Set 10 | sinjai
# Processing Record 36 of Set 10 | pacific grove
# Processing Record 37 of Set 10 | luwuk
# Processing Record 38 of Set 10 | kasongo-lunda
# Processing Record 39 of Set 10 | zolotinka
# City not found. Skipping...
# Processing Record 40 of Set 10 | mehran
# Processing Record 41 of Set 10 | piacabucu
# Processing Record 42 of Set 10 | beitbridge
# Processing Record 43 of Set 10 | folldal
# Processing Record 44 of Set 10 | gushikawa
# Processing Record 45 of Set 10 | san andres
# Processing Record 46 of Set 10 | liminangcong
# City not found. Skipping...
# Processing Record 47 of Set 10 | high level
# Processing Record 48 of Set 10 | nortelandia
# Processing Record 49 of Set 10 | chapais
# Processing Record 50 of Set 10 | zhanaozen
# Processing Record 1 of Set 11 | kayerkan
# Processing Record 2 of Set 11 | hamilton
# Processing Record 3 of Set 11 | emerald
# Processing Record 4 of Set 11 | bull savanna
# Processing Record 5 of Set 11 | gamboma
# Processing Record 6 of Set 11 | oda
# Processing Record 7 of Set 11 | moscow
# Processing Record 8 of Set 11 | kanniyakumari
# Processing Record 9 of Set 11 | stillwater
# Processing Record 10 of Set 11 | qasigiannguit
# Processing Record 11 of Set 11 | yaan
# Processing Record 12 of Set 11 | turbat
# Processing Record 13 of Set 11 | siyabuswa
# Processing Record 14 of Set 11 | hailar
# Processing Record 15 of Set 11 | haademeeste
# City not found. Skipping...
# Processing Record 16 of Set 11 | opunake
# Processing Record 17 of Set 11 | makakilo city
# Processing Record 18 of Set 11 | nioki
# Processing Record 19 of Set 11 | garissa
# Processing Record 20 of Set 11 | giengen
# City not found. Skipping...
# Processing Record 21 of Set 11 | srandakan
# Processing Record 22 of Set 11 | cumaribo
# City not found. Skipping...
# Processing Record 23 of Set 11 | champerico
# Processing Record 24 of Set 11 | jawhar
# Processing Record 25 of Set 11 | longlac
# City not found. Skipping...
# Processing Record 26 of Set 11 | monroe
# Processing Record 27 of Set 11 | dongsheng
# Processing Record 28 of Set 11 | mende
# Processing Record 29 of Set 11 | berbera
# Processing Record 30 of Set 11 | thinadhoo
# Processing Record 31 of Set 11 | hambantota
# Processing Record 32 of Set 11 | ixtapa
# Processing Record 33 of Set 11 | antofagasta
# Processing Record 34 of Set 11 | potam
# Processing Record 35 of Set 11 | thai binh
# Processing Record 36 of Set 11 | vanavara
# Processing Record 37 of Set 11 | genhe
# Processing Record 38 of Set 11 | atikokan
# Processing Record 39 of Set 11 | copacabana
# Processing Record 40 of Set 11 | kungurtug
# Processing Record 41 of Set 11 | isla mujeres
# Processing Record 42 of Set 11 | neuquen
# Processing Record 43 of Set 11 | tocopilla
# Processing Record 44 of Set 11 | houma
# Processing Record 45 of Set 11 | sanming
# Processing Record 46 of Set 11 | carutapera
# Processing Record 47 of Set 11 | muzquiz
# City not found. Skipping...
# Processing Record 48 of Set 11 | kirakira
# Processing Record 49 of Set 11 | yinchuan
# Processing Record 50 of Set 11 | khash
# Processing Record 1 of Set 12 | eatonton
# Processing Record 2 of Set 12 | jiazi
# Processing Record 3 of Set 12 | auki
# Processing Record 4 of Set 12 | sumenep
# Processing Record 5 of Set 12 | jujuy
# City not found. Skipping...
# Processing Record 6 of Set 12 | almaznyy
# Processing Record 7 of Set 12 | beian
# Processing Record 8 of Set 12 | ostersund
# Processing Record 9 of Set 12 | gushi
# Processing Record 10 of Set 12 | harnosand
# Processing Record 11 of Set 12 | itaqui
# Processing Record 12 of Set 12 | owando
# Processing Record 13 of Set 12 | buin
# Processing Record 14 of Set 12 | ituacu
# Processing Record 15 of Set 12 | codrington
# Processing Record 16 of Set 12 | mocambique
# City not found. Skipping...
# Processing Record 17 of Set 12 | sabang
# Processing Record 18 of Set 12 | maldonado
# Processing Record 19 of Set 12 | aflu
# City not found. Skipping...
# Processing Record 20 of Set 12 | chandur bazar
# Processing Record 21 of Set 12 | hasaki
# Processing Record 22 of Set 12 | dalbandin
# Processing Record 23 of Set 12 | nhulunbuy
# Processing Record 24 of Set 12 | salym
# Processing Record 25 of Set 12 | abbeville
# Processing Record 26 of Set 12 | asyut
# Processing Record 27 of Set 12 | pipri
# Processing Record 28 of Set 12 | eydhafushi
# Processing Record 29 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 30 of Set 12 | ciudad guayana
# Processing Record 31 of Set 12 | harbour breton
# Processing Record 32 of Set 12 | macroom
# Processing Record 33 of Set 12 | mehamn
# Processing Record 34 of Set 12 | yzeure
# Processing Record 35 of Set 12 | nesterov
# Processing Record 36 of Set 12 | stokmarknes
# Processing Record 37 of Set 12 | maniitsoq
# Processing Record 38 of Set 12 | gimli
# Processing Record 39 of Set 12 | domoni
# Processing Record 40 of Set 12 | manggar
# Processing Record 41 of Set 12 | oktyabrskiy
# Processing Record 42 of Set 12 | lander
# Processing Record 43 of Set 12 | dunedin
# Processing Record 44 of Set 12 | nhamunda
# Processing Record 45 of Set 12 | halalo
# City not found. Skipping...
# Processing Record 46 of Set 12 | viligili
# City not found. Skipping...
# Processing Record 47 of Set 12 | te anau
# Processing Record 48 of Set 12 | college
# Processing Record 49 of Set 12 | pivijay
# Processing Record 50 of Set 12 | pucallpa
# Processing Record 1 of Set 13 | montepuez
# Processing Record 2 of Set 13 | kyabe
# Processing Record 3 of Set 13 | abaza
# Processing Record 4 of Set 13 | xichang
# Processing Record 5 of Set 13 | ruatoria
# City not found. Skipping...
# Processing Record 6 of Set 13 | milingimbi
# City not found. Skipping...
# Processing Record 7 of Set 13 | tsukumi
# Processing Record 8 of Set 13 | ganzhou
# Processing Record 9 of Set 13 | tunceli
# Processing Record 10 of Set 13 | tabuk
# Processing Record 11 of Set 13 | uthal
# Processing Record 12 of Set 13 | batagay
# Processing Record 13 of Set 13 | portoferraio
# Processing Record 14 of Set 13 | eyl
# Processing Record 15 of Set 13 | kloulklubed
# Processing Record 16 of Set 13 | raton
# Processing Record 17 of Set 13 | pinega
# Processing Record 18 of Set 13 | omsukchan
# Processing Record 19 of Set 13 | acuna
# City not found. Skipping...
# Processing Record 20 of Set 13 | portland
# Processing Record 21 of Set 13 | helena
# Processing Record 22 of Set 13 | puerto madryn
# Processing Record 23 of Set 13 | biltine
# Processing Record 24 of Set 13 | mount isa
# Processing Record 25 of Set 13 | guaymas
# Processing Record 26 of Set 13 | roviai
# Processing Record 27 of Set 13 | oksfjord
# Processing Record 28 of Set 13 | komsomolskiy
# Processing Record 29 of Set 13 | varfurile
# Processing Record 30 of Set 13 | bichura
# Processing Record 31 of Set 13 | uvira
# Processing Record 32 of Set 13 | awbari
# Processing Record 33 of Set 13 | killam
# Processing Record 34 of Set 13 | lazaro cardenas
# Processing Record 35 of Set 13 | saint-louis
# Processing Record 36 of Set 13 | lenger
# Processing Record 37 of Set 13 | petropavlovsk-kamchatskiy
# Processing Record 38 of Set 13 | changji
# Processing Record 39 of Set 13 | artyk
# City not found. Skipping...
# Processing Record 40 of Set 13 | teya
# Processing Record 41 of Set 13 | mumbwa
# Processing Record 42 of Set 13 | severo-yeniseyskiy
# Processing Record 43 of Set 13 | shebunino
# Processing Record 44 of Set 13 | naryan-mar
# Processing Record 45 of Set 13 | fuzhou
# Processing Record 46 of Set 13 | taksimo
# Processing Record 47 of Set 13 | coquimbo
# Processing Record 48 of Set 13 | koroni
# Processing Record 49 of Set 13 | lindsay
# Processing Record 50 of Set 13 | teguise
# Processing Record 1 of Set 14 | priargunsk
# Processing Record 2 of Set 14 | rambha
# Processing Record 3 of Set 14 | lolua
# City not found. Skipping...
# Processing Record 4 of Set 14 | karpogory
# Processing Record 5 of Set 14 | aswan
# Processing Record 6 of Set 14 | ilo
# Processing Record 7 of Set 14 | northam
# Processing Record 8 of Set 14 | belmonte
# Processing Record 9 of Set 14 | melbu
# Processing Record 10 of Set 14 | surt
# Processing Record 11 of Set 14 | pevek
# Processing Record 12 of Set 14 | dakar
# Processing Record 13 of Set 14 | sao gabriel da cachoeira
# Processing Record 14 of Set 14 | aleksandrovka
# Processing Record 15 of Set 14 | kamenskoye
# City not found. Skipping...
# Processing Record 16 of Set 14 | nagayo
# City not found. Skipping...
# Processing Record 17 of Set 14 | gemena
# City not found. Skipping...
# Processing Record 18 of Set 14 | yamada
# City not found. Skipping...
# Processing Record 19 of Set 14 | holme
# City not found. Skipping...
# Processing Record 20 of Set 14 | diphu
# City not found. Skipping...
# Processing Record 21 of Set 14 | soto la marina
# City not found. Skipping...
# Processing Record 22 of Set 14 | chama
# City not found. Skipping...
# Processing Record 23 of Set 14 | christchurch
# Processing Record 24 of Set 14 | wajima
# Processing Record 25 of Set 14 | mago
# Processing Record 26 of Set 14 | casablanca
# Processing Record 27 of Set 14 | cotonou
# Processing Record 28 of Set 14 | vitoria da conquista
# Processing Record 29 of Set 14 | naze
# Processing Record 30 of Set 14 | serafimovich
# Processing Record 31 of Set 14 | ambanja
# Processing Record 32 of Set 14 | new albany
# Processing Record 33 of Set 14 | vaitape
# Processing Record 34 of Set 14 | sault sainte marie
# Processing Record 35 of Set 14 | badvel
# Processing Record 36 of Set 14 | kaman
# Processing Record 37 of Set 14 | dinsor
# City not found. Skipping...
# Processing Record 38 of Set 14 | pozo colorado
# Processing Record 39 of Set 14 | kalmunai
# Processing Record 40 of Set 14 | dzheyrakh
# Processing Record 41 of Set 14 | hobyo
# Processing Record 42 of Set 14 | terrace bay
# Processing Record 43 of Set 14 | wynyard
# Processing Record 44 of Set 14 | mackay
# Processing Record 45 of Set 14 | siayan
# Processing Record 46 of Set 14 | abu zabad
# Processing Record 47 of Set 14 | lavrentiya
# Processing Record 48 of Set 14 | jishou
# Processing Record 49 of Set 14 | quatre cocos
# Processing Record 50 of Set 14 | phan thiet
# Processing Record 1 of Set 15 | hurricane
# Processing Record 2 of Set 15 | luangwa
# Processing Record 3 of Set 15 | mumford
# Processing Record 4 of Set 15 | lakhisarai
# Processing Record 5 of Set 15 | chitungwiza
# Processing Record 6 of Set 15 | dharchula
# Processing Record 7 of Set 15 | tieling
# Processing Record 8 of Set 15 | huarmey
# Processing Record 9 of Set 15 | laurel
# Processing Record 10 of Set 15 | inirida
# Processing Record 11 of Set 15 | moyamba
# Processing Record 12 of Set 15 | penarroya-pueblonuevo
# Processing Record 13 of Set 15 | orgun
# City not found. Skipping...
# Processing Record 14 of Set 15 | ushtobe
# Processing Record 15 of Set 15 | hirara
# Processing Record 16 of Set 15 | utiroa
# City not found. Skipping...
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | port-cartier
# Processing Record 19 of Set 15 | khor
# Processing Record 20 of Set 15 | eureka
# Processing Record 21 of Set 15 | sabha
# Processing Record 22 of Set 15 | iranshahr
# Processing Record 23 of Set 15 | faya
# Processing Record 24 of Set 15 | linjiang
# Processing Record 25 of Set 15 | tsabong
# Processing Record 26 of Set 15 | namatanai
# Processing Record 27 of Set 15 | narsaq
# Processing Record 28 of Set 15 | pundaguitan
# Processing Record 29 of Set 15 | mostovskoy
# Processing Record 30 of Set 15 | canarana
# Processing Record 31 of Set 15 | riyadh
# Processing Record 32 of Set 15 | zaozerne
# Processing Record 33 of Set 15 | krasnoarmeysk
# Processing Record 34 of Set 15 | bandarbeyla
# Processing Record 35 of Set 15 | batemans bay
# Processing Record 36 of Set 15 | shenjiamen
# Processing Record 37 of Set 15 | chilca
# Processing Record 38 of Set 15 | dwarka
# Processing Record 39 of Set 15 | mahibadhoo
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#                City Country      Lat       Lng  Max Temp  Humidity  \
# 0         Aginskoye      RU  51.1000  114.5300     21.60        84
# 1             Kutum      SD  14.2000   24.6667     48.85        41
# 2          Valdivia      CL -39.8142  -73.2459     46.49        81
# 3        Smoky Lake      CA  54.1169 -112.4686     20.12        93
# 4        Butaritari      KI   3.0707  172.7902     81.27        74
# 5  Vale Da Amoreira      PT  39.0697   -7.6985     52.88        93
# 6             Balad      IQ  34.0164   44.1453     45.55        54
# 7           Ushuaia      AR -54.8000  -68.3000     49.66        81
# 8         Jamestown      US  42.0970  -79.2353     32.02        72
# 9           Tselina      RU  46.5338   41.0328     11.73        83
#
#    Cloudiness  Wind Speed      Description
# 0          91        1.45  overcast clouds
# 1          64        6.24    broken clouds
# 2           0        1.74        clear sky
# 3         100        1.14  overcast clouds
# 4          16       12.75       few clouds
# 5         100        4.47  overcast clouds
# 6           0        8.79        clear sky
# 7           0       16.11        clear sky
# 8          75        5.75             mist
# 9          90       24.20  overcast clouds

# %%
# Display the data types of each column by using the dtypes Pandas function
city_data_df.dtypes
# Out:
# City            object
# Country         object
# Lat            float64
# Lng            float64
# Max Temp       float64
# Humidity         int64
# Cloudiness       int64
# Wind Speed     float64
# Description     object
# dtype: object

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file)

# %% [markdown]
# ## Use the `np.random.uniform` function to generate a new set of 2,000 random latitudes and 2,000 longitudes.

# %%
# Create a set of random latitude and longitude combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)

# Use the zip function to create an iterator of tuples containing the latitude and longitude combinations
lat_lngs = # YOUR CODE HERE

# %%
# Add the latitudes and longitudes to a list
coordinates = # YOUR CODE HERE

# %% [markdown]
# ## Use the `citipy` module to get the nearest city for each latitude and longitude combination.

# %%
# Create an empty list for holding the cities
# YOUR CODE HERE

# Use a for loop to identify nearest city for each latitude and longitude combination using the citipy module
for coordinate in coordinates:
    # Use the citipy module to identify the nearest city to the current coordinate
    city = # YOUR CODE HERE
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        # YOUR CODE HERE

# Print the city count to confirm sufficient count
# YOUR CODE HERE
# Out:
# 751

# %% [markdown]
# ## Import your OpenWeatherMap's API key and assemble the API call URL as a string variable. Recall to edit the `config.py` file to add your API key.

# %%
# Import the requests library
import requests

# Import the time library
import time

# Import the datetime module from the datetime library
from datetime import datetime

# Import the OpenWeatherMap's API key
from config import weather_api_key

# %%
# Assemble the OpenWeatherMap's API call
url = # YOUR CODE HERE

# %% [markdown]
# ## Retrieve the following information from the API call.
#
# - The latitude and longitude
# - The Max temperature
# - The % humidity
# - The % cloudiness
# - The Wind speed
# - The Weather description, i.e., cloudy, fog, light rain, clear sky, etc.

# %%
# Create an empty list to hold weather data for each city
city_data = []

# Print a message to indicate that the data retrieval starts
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters and set them to 1
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data for each city
for i, city in enumerate(cities):
        
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)

    # Create an endpoint URL for each city
    city_url = url + "&q=" + city.replace(" ","+")
    
    # Log the url, record, and set numbers
    print(f"Processing Record {record_count} of Set {set_count} | {city}")

    # Add 1 to the record count
    record_count += 1

    # Run an API request for each of the cities
    try:
        city_weather = requests.get(city_url).json()
        # Parse out the latitude, longitude, max temp, humidity, cloudiness, wind, country, and weather description
        # YOUR CODE HERE       
            
        # Append the city information into the city_data list
        # YOUR CODE HERE
    
    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass

# Indicate that the data retrieval is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | bluff
# Processing Record 2 of Set 1 | chhukha
# City not found. Skipping...
# Processing Record 3 of Set 1 | metro
# Processing Record 4 of Set 1 | pacific grove
# Processing Record 5 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 6 of Set 1 | saint george
# Processing Record 7 of Set 1 | mataura
# Processing Record 8 of Set 1 | biltine
# Processing Record 9 of Set 1 | gao
# Processing Record 10 of Set 1 | hithadhoo
# Processing Record 11 of Set 1 | bambous virieux
# Processing Record 12 of Set 1 | rikitea
# Processing Record 13 of Set 1 | pingzhuang
# Processing Record 14 of Set 1 | thompson
# Processing Record 15 of Set 1 | namatanai
# Processing Record 16 of Set 1 | agadez
# Processing Record 17 of Set 1 | asau
# Processing Record 18 of Set 1 | leningradskiy
# Processing Record 19 of Set 1 | port macquarie
# Processing Record 20 of Set 1 | hilo
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | new norfolk
# Processing Record 23 of Set 1 | mahebourg
# Processing Record 24 of Set 1 | poum
# Processing Record 25 of Set 1 | punta arenas
# Processing Record 26 of Set 1 | camacupa
# Processing Record 27 of Set 1 | sao filipe
# Processing Record 28 of Set 1 | saint-augustin
# Processing Record 29 of Set 1 | awjilah
# Processing Record 30 of Set 1 | upernavik
# Processing Record 31 of Set 1 | arima
# Processing Record 32 of Set 1 | bethel
# Processing Record 33 of Set 1 | wicklow
# Processing Record 34 of Set 1 | nuuk
# Processing Record 35 of Set 1 | brovary
# Processing Record 36 of Set 1 | coruripe
# Processing Record 37 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 38 of Set 1 | acapulco
# Processing Record 39 of Set 1 | port elizabeth
# Processing Record 40 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 41 of Set 1 | port augusta
# Processing Record 42 of Set 1 | lompoc
# Processing Record 43 of Set 1 | gerash
# Processing Record 44 of Set 1 | nadym
# Processing Record 45 of Set 1 | nemuro
# Processing Record 46 of Set 1 | kalemie
# Processing Record 47 of Set 1 | puerto ayora
# Processing Record 48 of Set 1 | namtsy
# Processing Record 49 of Set 1 | barrow
# Processing Record 50 of Set 1 | tuktoyaktuk
# Processing Record 1 of Set 2 | san quintin
# Processing Record 2 of Set 2 | severo-kurilsk
# Processing Record 3 of Set 2 | tasiilaq
# Processing Record 4 of Set 2 | oktyabrskiy
# Processing Record 5 of Set 2 | cape town
# Processing Record 6 of Set 2 | prince albert
# Processing Record 7 of Set 2 | mandalgovi
# Processing Record 8 of Set 2 | djibo
# Processing Record 9 of Set 2 | u thong
# Processing Record 10 of Set 2 | aranos
# Processing Record 11 of Set 2 | emerald
# Processing Record 12 of Set 2 | souillac
# Processing Record 13 of Set 2 | bredasdorp
# Processing Record 14 of Set 2 | kondinskoye
# Processing Record 15 of Set 2 | liuhe
# Processing Record 16 of Set 2 | langsa
# Processing Record 17 of Set 2 | khonuu
# City not found. Skipping...
# Processing Record 18 of Set 2 | hermanus
# Processing Record 19 of Set 2 | chuy
# Processing Record 20 of Set 2 | vaini
# Processing Record 21 of Set 2 | mongo
# Processing Record 22 of Set 2 | luderitz
# Processing Record 23 of Set 2 | pitimbu
# Processing Record 24 of Set 2 | slave lake
# Processing Record 25 of Set 2 | sheridan
# Processing Record 26 of Set 2 | iqaluit
# Processing Record 27 of Set 2 | karratha
# Processing Record 28 of Set 2 | qaanaaq
# Processing Record 29 of Set 2 | sabang
# Processing Record 30 of Set 2 | naze
# Processing Record 31 of Set 2 | maridi
# Processing Record 32 of Set 2 | busselton
# Processing Record 33 of Set 2 | khatanga
# Processing Record 34 of Set 2 | maragogi
# Processing Record 35 of Set 2 | ambulu
# Processing Record 36 of Set 2 | port alfred
# Processing Record 37 of Set 2 | hede
# Processing Record 38 of Set 2 | margate
# Processing Record 39 of Set 2 | vaitupu
# City not found. Skipping...
# Processing Record 40 of Set 2 | jamestown
# Processing Record 41 of Set 2 | dingle
# Processing Record 42 of Set 2 | bilibino
# Processing Record 43 of Set 2 | yellowknife
# Processing Record 44 of Set 2 | mar del plata
# Processing Record 45 of Set 2 | severo-yeniseyskiy
# Processing Record 46 of Set 2 | ancud
# Processing Record 47 of Set 2 | kodiak
# Processing Record 48 of Set 2 | castro
# Processing Record 49 of Set 2 | abha
# Processing Record 50 of Set 2 | torbay
# Processing Record 1 of Set 3 | vestmanna
# Processing Record 2 of Set 3 | norman wells
# Processing Record 3 of Set 3 | baruun-urt
# Processing Record 4 of Set 3 | chengde
# Processing Record 5 of Set 3 | rincon
# Processing Record 6 of Set 3 | okha
# Processing Record 7 of Set 3 | nikolskoye
# Processing Record 8 of Set 3 | avarua
# Processing Record 9 of Set 3 | lanas
# Processing Record 10 of Set 3 | morro bay
# Processing Record 11 of Set 3 | tiksi
# Processing Record 12 of Set 3 | westport
# Processing Record 13 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 14 of Set 3 | beauchamps
# Processing Record 15 of Set 3 | jalu
# Processing Record 16 of Set 3 | chokurdakh
# Processing Record 17 of Set 3 | albany
# Processing Record 18 of Set 3 | kapaa
# Processing Record 19 of Set 3 | tura
# Processing Record 20 of Set 3 | phan rang
# City not found. Skipping...
# Processing Record 21 of Set 3 | ambilobe
# Processing Record 22 of Set 3 | hamilton
# Processing Record 23 of Set 3 | amalapuram
# Processing Record 24 of Set 3 | marsa matruh
# Processing Record 25 of Set 3 | ribeira grande
# Processing Record 26 of Set 3 | bulgan
# Processing Record 27 of Set 3 | dikson
# Processing Record 28 of Set 3 | edremit
# Processing Record 29 of Set 3 | warqla
# City not found. Skipping...
# Processing Record 30 of Set 3 | peterhead
# Processing Record 31 of Set 3 | cabedelo
# Processing Record 32 of Set 3 | sorvag
# City not found. Skipping...
# Processing Record 33 of Set 3 | kushima
# Processing Record 34 of Set 3 | potam
# Processing Record 35 of Set 3 | arraial do cabo
# Processing Record 36 of Set 3 | saint anthony
# Processing Record 37 of Set 3 | makokou
# Processing Record 38 of Set 3 | carnarvon
# Processing Record 39 of Set 3 | grand gaube
# Processing Record 40 of Set 3 | fuyu
# Processing Record 41 of Set 3 | butaritari
# Processing Record 42 of Set 3 | atuona
# Processing Record 43 of Set 3 | morehead
# Processing Record 44 of Set 3 | port lincoln
# Processing Record 45 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 46 of Set 3 | ushtobe
# Processing Record 47 of Set 3 | ponta do sol
# Processing Record 48 of Set 3 | manokwari
# Processing Record 49 of Set 3 | chalchihuites
# Processing Record 50 of Set 3 | zeya
# Processing Record 1 of Set 4 | lyngseidet
# Processing Record 2 of Set 4 | berlevag
# Processing Record 3 of Set 4 | haines junction
# Processing Record 4 of Set 4 | novaya igirma
# Processing Record 5 of Set 4 | narsaq
# Processing Record 6 of Set 4 | longyearbyen
# Processing Record 7 of Set 4 | bullhead city
# Processing Record 8 of Set 4 | opuwo
# Processing Record 9 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 10 of Set 4 | mys shmidta
# City not found. Skipping...
# Processing Record 11 of Set 4 | burgos
# Processing Record 12 of Set 4 | samusu
# City not found. Skipping...
# Processing Record 13 of Set 4 | lata
# Processing Record 14 of Set 4 | brandon
# Processing Record 15 of Set 4 | naklo nad notecia
# Processing Record 16 of Set 4 | brigantine
# Processing Record 17 of Set 4 | storm lake
# Processing Record 18 of Set 4 | cidreira
# Processing Record 19 of Set 4 | matadi
# Processing Record 20 of Set 4 | mandiana
# Processing Record 21 of Set 4 | falam
# Processing Record 22 of Set 4 | aurdal
# Processing Record 23 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 24 of Set 4 | ayer itam
# City not found. Skipping...
# Processing Record 25 of Set 4 | strezhevoy
# Processing Record 26 of Set 4 | mbanza-ngungu
# Processing Record 27 of Set 4 | kamaishi
# Processing Record 28 of Set 4 | georgetown
# Processing Record 29 of Set 4 | hobart
# Processing Record 30 of Set 4 | bogoslovka
# Processing Record 31 of Set 4 | atar
# Processing Record 32 of Set 4 | labuhan
# Processing Record 33 of Set 4 | havelock
# Processing Record 34 of Set 4 | ravar
# Processing Record 35 of Set 4 | tabiauea
# City not found. Skipping...
# Processing Record 36 of Set 4 | pingliang
# Processing Record 37 of Set 4 | saleaula
# City not found. Skipping...
# Processing Record 38 of Set 4 | salalah
# Processing Record 39 of Set 4 | saint-philippe
# Processing Record 40 of Set 4 | floro
# Processing Record 41 of Set 4 | goya
# Processing Record 42 of Set 4 | cheney
# Processing Record 43 of Set 4 | tumannyy
# City not found. Skipping...
# Processing Record 44 of Set 4 | sumbawa
# City not found. Skipping...
# Processing Record 45 of Set 4 | aswan
# Processing Record 46 of Set 4 | yining
# Processing Record 47 of Set 4 | katsuura
# Processing Record 48 of Set 4 | shipunovo
# Processing Record 49 of Set 4 | shevchenkove
# Processing Record 50 of Set 4 | henties bay
# Processing Record 1 of Set 5 | tutoia
# Processing Record 2 of Set 5 | cusset
# Processing Record 3 of Set 5 | los angeles
# Processing Record 4 of Set 5 | coquimbo
# Processing Record 5 of Set 5 | lukang
# Processing Record 6 of Set 5 | taoudenni
# Processing Record 7 of Set 5 | sarangani
# Processing Record 8 of Set 5 | urubicha
# Processing Record 9 of Set 5 | lasa
# Processing Record 10 of Set 5 | ialibu
# Processing Record 11 of Set 5 | alofi
# Processing Record 12 of Set 5 | marsh harbour
# Processing Record 13 of Set 5 | hofn
# Processing Record 14 of Set 5 | bandarbeyla
# Processing Record 15 of Set 5 | makung
# City not found. Skipping...
# Processing Record 16 of Set 5 | palmer
# Processing Record 17 of Set 5 | tautira
# Processing Record 18 of Set 5 | yar-sale
# Processing Record 19 of Set 5 | vila velha
# Processing Record 20 of Set 5 | saint-francois
# Processing Record 21 of Set 5 | vardo
# Processing Record 22 of Set 5 | saskylakh
# Processing Record 23 of Set 5 | andilamena
# Processing Record 24 of Set 5 | luau
# Processing Record 25 of Set 5 | vacha
# Processing Record 26 of Set 5 | jamnagar
# Processing Record 27 of Set 5 | east london
# Processing Record 28 of Set 5 | itaituba
# Processing Record 29 of Set 5 | colares
# Processing Record 30 of Set 5 | meyungs
# City not found. Skipping...
# Processing Record 31 of Set 5 | constitucion
# Processing Record 32 of Set 5 | jacareacanga
# Processing Record 33 of Set 5 | port hardy
# Processing Record 34 of Set 5 | kjollefjord
# Processing Record 35 of Set 5 | tiznit
# Processing Record 36 of Set 5 | port hedland
# Processing Record 37 of Set 5 | araouane
# Processing Record 38 of Set 5 | cap-chat
# Processing Record 39 of Set 5 | saldanha
# Processing Record 40 of Set 5 | maua
# Processing Record 41 of Set 5 | hun
# Processing Record 42 of Set 5 | tamasi
# Processing Record 43 of Set 5 | paita
# Processing Record 44 of Set 5 | cherskiy
# Processing Record 45 of Set 5 | pangody
# Processing Record 46 of Set 5 | cayenne
# Processing Record 47 of Set 5 | sibolga
# Processing Record 48 of Set 5 | faya
# Processing Record 49 of Set 5 | kavieng
# Processing Record 50 of Set 5 | padang
# Processing Record 1 of Set 6 | aykhal
# Processing Record 2 of Set 6 | dukat
# Processing Record 3 of Set 6 | camacha
# Processing Record 4 of Set 6 | hay river
# Processing Record 5 of Set 6 | evensk
# Processing Record 6 of Set 6 | yerofey pavlovich
# Processing Record 7 of Set 6 | bada
# Processing Record 8 of Set 6 | petropavlovsk-kamchatskiy
# Processing Record 9 of Set 6 | provideniya
# Processing Record 10 of Set 6 | tsogni
# Processing Record 11 of Set 6 | bilma
# Processing Record 12 of Set 6 | barraute
# Processing Record 13 of Set 6 | bantou
# Processing Record 14 of Set 6 | eydhafushi
# Processing Record 15 of Set 6 | beloha
# Processing Record 16 of Set 6 | dunedin
# Processing Record 17 of Set 6 | general roca
# Processing Record 18 of Set 6 | puerto madryn
# Processing Record 19 of Set 6 | tigil
# Processing Record 20 of Set 6 | nizhniy kuranakh
# Processing Record 21 of Set 6 | inta
# Processing Record 22 of Set 6 | antofagasta
# Processing Record 23 of Set 6 | inhambane
# Processing Record 24 of Set 6 | ballina
# Processing Record 25 of Set 6 | vrises
# Processing Record 26 of Set 6 | chapais
# Processing Record 27 of Set 6 | bac lieu
# Processing Record 28 of Set 6 | clyde river
# Processing Record 29 of Set 6 | gorontalo
# Processing Record 30 of Set 6 | fairview
# Processing Record 31 of Set 6 | puerto colombia
# Processing Record 32 of Set 6 | buraydah
# Processing Record 33 of Set 6 | mansa
# Processing Record 34 of Set 6 | nikel
# Processing Record 35 of Set 6 | townsville
# Processing Record 36 of Set 6 | mezen
# Processing Record 37 of Set 6 | jan kempdorp
# Processing Record 38 of Set 6 | oranjestad
# Processing Record 39 of Set 6 | elblag
# Processing Record 40 of Set 6 | petawawa
# Processing Record 41 of Set 6 | mangan
# Processing Record 42 of Set 6 | karpathos
# Processing Record 43 of Set 6 | shingu
# Processing Record 44 of Set 6 | alta floresta
# Processing Record 45 of Set 6 | nguiu
# City not found. Skipping...
# Processing Record 46 of Set 6 | bengkulu
# Processing Record 47 of Set 6 | touros
# Processing Record 48 of Set 6 | sept-iles
# Processing Record 49 of Set 6 | bereslavka
# Processing Record 50 of Set 6 | half moon bay
# Processing Record 1 of Set 7 | esperance
# Processing Record 2 of Set 7 | maniitsoq
# Processing Record 3 of Set 7 | progreso
# Processing Record 4 of Set 7 | luwuk
# Processing Record 5 of Set 7 | fukue
# Processing Record 6 of Set 7 | san rafael
# Processing Record 7 of Set 7 | pasni
# Processing Record 8 of Set 7 | talcahuano
# Processing Record 9 of Set 7 | fayaoue
# Processing Record 10 of Set 7 | sciacca
# Processing Record 11 of Set 7 | puerto escondido
# Processing Record 12 of Set 7 | koslan
# Processing Record 13 of Set 7 | belen
# Processing Record 14 of Set 7 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 7 | jizan
# Processing Record 16 of Set 7 | imbituba
# Processing Record 17 of Set 7 | kroya
# Processing Record 18 of Set 7 | jining
# Processing Record 19 of Set 7 | tecoanapa
# Processing Record 20 of Set 7 | harper
# Processing Record 21 of Set 7 | thoen
# Processing Record 22 of Set 7 | pisco
# Processing Record 23 of Set 7 | hohhot
# Processing Record 24 of Set 7 | kapit
# Processing Record 25 of Set 7 | kitimat
# Processing Record 26 of Set 7 | cosala
# Processing Record 27 of Set 7 | the valley
# Processing Record 28 of Set 7 | aflu
# City not found. Skipping...
# Processing Record 29 of Set 7 | lamu
# Processing Record 30 of Set 7 | talnakh
# Processing Record 31 of Set 7 | quatre cocos
# Processing Record 32 of Set 7 | kruisfontein
# Processing Record 33 of Set 7 | kieta
# Processing Record 34 of Set 7 | riohacha
# Processing Record 35 of Set 7 | roshchino
# Processing Record 36 of Set 7 | kota kinabalu
# Processing Record 37 of Set 7 | santa maria
# Processing Record 38 of Set 7 | hasaki
# Processing Record 39 of Set 7 | pangnirtung
# Processing Record 40 of Set 7 | miyako
# Processing Record 41 of Set 7 | itarema
# Processing Record 42 of Set 7 | amderma
# City not found. Skipping...
# Processing Record 43 of Set 7 | athlone
# Processing Record 44 of Set 7 | la libertad
# Processing Record 45 of Set 7 | mitsamiouli
# Processing Record 46 of Set 7 | cabo san lucas
# Processing Record 47 of Set 7 | yantal
# Processing Record 48 of Set 7 | aklavik
# Processing Record 49 of Set 7 | parakou
# Processing Record 50 of Set 7 | madison
# Processing Record 1 of Set 8 | wulanhaote
# City not found. Skipping...
# Processing Record 2 of Set 8 | sinop
# Processing Record 3 of Set 8 | kaitangata
# Processing Record 4 of Set 8 | santa maria del real
# Processing Record 5 of Set 8 | bambanglipuro
# Processing Record 6 of Set 8 | kidal
# Processing Record 7 of Set 8 | darhan
# Processing Record 8 of Set 8 | avera
# Processing Record 9 of Set 8 | belyy yar
# Processing Record 10 of Set 8 | la joya
# Processing Record 11 of Set 8 | orapa
# Processing Record 12 of Set 8 | umm durman
# City not found. Skipping...
# Processing Record 13 of Set 8 | doctor pedro p. pena
# City not found. Skipping...
# Processing Record 14 of Set 8 | ontario
# Processing Record 15 of Set 8 | huitziltepec
# Processing Record 16 of Set 8 | tianpeng
# Processing Record 17 of Set 8 | semey
# Processing Record 18 of Set 8 | nanortalik
# Processing Record 19 of Set 8 | kutum
# Processing Record 20 of Set 8 | tessalit
# Processing Record 21 of Set 8 | sitka
# Processing Record 22 of Set 8 | cilegon
# Processing Record 23 of Set 8 | never
# Processing Record 24 of Set 8 | tsihombe
# City not found. Skipping...
# Processing Record 25 of Set 8 | karaul
# City not found. Skipping...
# Processing Record 26 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 27 of Set 8 | hit
# Processing Record 28 of Set 8 | bosaso
# Processing Record 29 of Set 8 | taft
# Processing Record 30 of Set 8 | port blair
# Processing Record 31 of Set 8 | gold coast
# Processing Record 32 of Set 8 | rawson
# Processing Record 33 of Set 8 | veseloyarsk
# Processing Record 34 of Set 8 | konevo
# Processing Record 35 of Set 8 | goulburn
# Processing Record 36 of Set 8 | balkhash
# Processing Record 37 of Set 8 | yuli
# Processing Record 38 of Set 8 | ghanzi
# Processing Record 39 of Set 8 | puri
# Processing Record 40 of Set 8 | cockburn town
# Processing Record 41 of Set 8 | fairbanks
# Processing Record 42 of Set 8 | grootfontein
# Processing Record 43 of Set 8 | kaniama
# Processing Record 44 of Set 8 | palabuhanratu
# City not found. Skipping...
# Processing Record 45 of Set 8 | liverpool
# Processing Record 46 of Set 8 | umm lajj
# Processing Record 47 of Set 8 | eureka
# Processing Record 48 of Set 8 | tilichiki
# Processing Record 49 of Set 8 | viligili
# City not found. Skipping...
# Processing Record 50 of Set 8 | pyay
# Processing Record 1 of Set 9 | hwange
# Processing Record 2 of Set 9 | salmas
# Processing Record 3 of Set 9 | adrar
# Processing Record 4 of Set 9 | concordia
# Processing Record 5 of Set 9 | ostrovnoy
# Processing Record 6 of Set 9 | homer
# Processing Record 7 of Set 9 | lebu
# Processing Record 8 of Set 9 | borama
# City not found. Skipping...
# Processing Record 9 of Set 9 | lusambo
# Processing Record 10 of Set 9 | birjand
# Processing Record 11 of Set 9 | lagoa
# Processing Record 12 of Set 9 | faanui
# Processing Record 13 of Set 9 | alice springs
# Processing Record 14 of Set 9 | namibe
# Processing Record 15 of Set 9 | port-cartier
# Processing Record 16 of Set 9 | mujiayingzi
# Processing Record 17 of Set 9 | carauari
# Processing Record 18 of Set 9 | ballitoville
# Processing Record 19 of Set 9 | los llanos de aridane
# Processing Record 20 of Set 9 | boa vista
# Processing Record 21 of Set 9 | paka
# Processing Record 22 of Set 9 | fevralsk
# City not found. Skipping...
# Processing Record 23 of Set 9 | saryshagan
# City not found. Skipping...
# Processing Record 24 of Set 9 | bajil
# Processing Record 25 of Set 9 | san patricio
# Processing Record 26 of Set 9 | bathsheba
# Processing Record 27 of Set 9 | vila franca do campo
# Processing Record 28 of Set 9 | svetlogorsk
# Processing Record 29 of Set 9 | pevek
# Processing Record 30 of Set 9 | tiarei
# Processing Record 31 of Set 9 | sao desiderio
# Processing Record 32 of Set 9 | tabas
# Processing Record 33 of Set 9 | copiapo
# Processing Record 34 of Set 9 | suhbaatar
# Processing Record 35 of Set 9 | zhezkazgan
# Processing Record 36 of Set 9 | karachi
# Processing Record 37 of Set 9 | chagda
# City not found. Skipping...
# Processing Record 38 of Set 9 | edgewater
# Processing Record 39 of Set 9 | cururupu
# Processing Record 40 of Set 9 | golden
# Processing Record 41 of Set 9 | kudahuvadhoo
# Processing Record 42 of Set 9 | novo aripuana
# Processing Record 43 of Set 9 | moron
# Processing Record 44 of Set 9 | mareeba
# Processing Record 45 of Set 9 | shimonoseki
# Processing Record 46 of Set 9 | santa rosa
# Processing Record 47 of Set 9 | malaryta
# Processing Record 48 of Set 9 | bend
# Processing Record 49 of Set 9 | samalaeulu
# City not found. Skipping...
# Processing Record 50 of Set 9 | hami
# Processing Record 1 of Set 10 | marsabit
# Processing Record 2 of Set 10 | tual
# Processing Record 3 of Set 10 | naugarzan
# City not found. Skipping...
# Processing Record 4 of Set 10 | ahipara
# Processing Record 5 of Set 10 | nouadhibou
# Processing Record 6 of Set 10 | farah
# Processing Record 7 of Set 10 | shenjiamen
# Processing Record 8 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 9 of Set 10 | lulea
# Processing Record 10 of Set 10 | praia da vitoria
# Processing Record 11 of Set 10 | middelkerke
# Processing Record 12 of Set 10 | ulaanbaatar
# Processing Record 13 of Set 10 | erzin
# Processing Record 14 of Set 10 | kavaratti
# Processing Record 15 of Set 10 | broome
# Processing Record 16 of Set 10 | sterlibashevo
# Processing Record 17 of Set 10 | olavarria
# Processing Record 18 of Set 10 | shurugwi
# Processing Record 19 of Set 10 | eufaula
# Processing Record 20 of Set 10 | plettenberg bay
# Processing Record 21 of Set 10 | laguna
# Processing Record 22 of Set 10 | mount pleasant
# Processing Record 23 of Set 10 | lorengau
# Processing Record 24 of Set 10 | geraldton
# Processing Record 25 of Set 10 | chibuto
# Processing Record 26 of Set 10 | qinhuangdao
# Processing Record 27 of Set 10 | kemijarvi
# Processing Record 28 of Set 10 | ternate
# Processing Record 29 of Set 10 | perelyub
# Processing Record 30 of Set 10 | ayan
# Processing Record 31 of Set 10 | rio grande
# Processing Record 32 of Set 10 | meulaboh
# Processing Record 33 of Set 10 | nome
# Processing Record 34 of Set 10 | abdulino
# Processing Record 35 of Set 10 | gisborne
# Processing Record 36 of Set 10 | leshukonskoye
# Processing Record 37 of Set 10 | san andres
# Processing Record 38 of Set 10 | mullaitivu
# City not found. Skipping...
# Processing Record 39 of Set 10 | balagansk
# Processing Record 40 of Set 10 | skegness
# Processing Record 41 of Set 10 | sao joao da barra
# Processing Record 42 of Set 10 | chute-aux-outardes
# Processing Record 43 of Set 10 | peleduy
# Processing Record 44 of Set 10 | barcelona
# Processing Record 45 of Set 10 | macaboboni
# City not found. Skipping...
# Processing Record 46 of Set 10 | sao miguel do araguaia
# Processing Record 47 of Set 10 | isangel
# Processing Record 48 of Set 10 | khilok
# Processing Record 49 of Set 10 | emba
# Processing Record 50 of Set 10 | sanawad
# Processing Record 1 of Set 11 | belmonte
# Processing Record 2 of Set 11 | turtkul
# City not found. Skipping...
# Processing Record 3 of Set 11 | san francisco
# Processing Record 4 of Set 11 | ust-kut
# Processing Record 5 of Set 11 | airai
# Processing Record 6 of Set 11 | guerrero negro
# Processing Record 7 of Set 11 | anadyr
# Processing Record 8 of Set 11 | wajir
# Processing Record 9 of Set 11 | valleyview
# Processing Record 10 of Set 11 | veinticinco de mayo
# Processing Record 11 of Set 11 | baltiysk
# Processing Record 12 of Set 11 | shahrud
# Processing Record 13 of Set 11 | port-gentil
# Processing Record 14 of Set 11 | muisne
# Processing Record 15 of Set 11 | polyarnyy
# Processing Record 16 of Set 11 | fortuna
# Processing Record 17 of Set 11 | tongchuan
# Processing Record 18 of Set 11 | zhanaozen
# Processing Record 19 of Set 11 | omutinskoye
# City not found. Skipping...
# Processing Record 20 of Set 11 | marsaxlokk
# Processing Record 21 of Set 11 | yanam
# Processing Record 22 of Set 11 | kirakira
# Processing Record 23 of Set 11 | nyurba
# Processing Record 24 of Set 11 | balikpapan
# Processing Record 25 of Set 11 | ferkessedougou
# Processing Record 26 of Set 11 | sao felix do xingu
# Processing Record 27 of Set 11 | nanga eboko
# Processing Record 28 of Set 11 | nunkini
# Processing Record 29 of Set 11 | kostino
# Processing Record 30 of Set 11 | egvekinot
# Processing Record 31 of Set 11 | abnub
# Processing Record 32 of Set 11 | ajdabiya
# Processing Record 33 of Set 11 | codrington
# Processing Record 34 of Set 11 | pipri
# Processing Record 35 of Set 11 | galle
# Processing Record 36 of Set 11 | benghazi
# Processing Record 37 of Set 11 | morecambe
# Processing Record 38 of Set 11 | ostersund
# Processing Record 39 of Set 11 | nelson bay
# Processing Record 40 of Set 11 | roswell
# Processing Record 41 of Set 11 | norsup
# Processing Record 42 of Set 11 | bratsk
# Processing Record 43 of Set 11 | rocha
# Processing Record 44 of Set 11 | khash
# Processing Record 45 of Set 11 | gaffney
# Processing Record 46 of Set 11 | husavik
# Processing Record 47 of Set 11 | east moline
# Processing Record 48 of Set 11 | banyo
# Processing Record 49 of Set 11 | okhotsk
# Processing Record 50 of Set 11 | manicore
# Processing Record 1 of Set 12 | the pas
# Processing Record 2 of Set 12 | chissamba
# Processing Record 3 of Set 12 | zarubino
# Processing Record 4 of Set 12 | dabhol
# Processing Record 5 of Set 12 | esso
# Processing Record 6 of Set 12 | manama
# Processing Record 7 of Set 12 | wanning
# Processing Record 8 of Set 12 | yulara
# Processing Record 9 of Set 12 | pio xii
# Processing Record 10 of Set 12 | rosario oeste
# Processing Record 11 of Set 12 | ixtapa
# Processing Record 12 of Set 12 | camapua
# Processing Record 13 of Set 12 | vila
# Processing Record 14 of Set 12 | kamenskoye
# City not found. Skipping...
# Processing Record 15 of Set 12 | santa isabel do rio negro
# Processing Record 16 of Set 12 | amahai
# Processing Record 17 of Set 12 | churapcha
# Processing Record 18 of Set 12 | frontera
# Processing Record 19 of Set 12 | toulepleu
# City not found. Skipping...
# Processing Record 20 of Set 12 | montepuez
# Processing Record 21 of Set 12 | staryy nadym
# Processing Record 22 of Set 12 | sakakah
# Processing Record 23 of Set 12 | victoria
# Processing Record 24 of Set 12 | korla
# Processing Record 25 of Set 12 | ilulissat
# Processing Record 26 of Set 12 | simao
# Processing Record 27 of Set 12 | bundaberg
# Processing Record 28 of Set 12 | trairi
# Processing Record 29 of Set 12 | upata
# Processing Record 30 of Set 12 | mabaruma
# Processing Record 31 of Set 12 | banjar
# Processing Record 32 of Set 12 | plouzane
# Processing Record 33 of Set 12 | chernyshevskiy
# Processing Record 34 of Set 12 | sangar
# Processing Record 35 of Set 12 | antalaha
# Processing Record 36 of Set 12 | kurskaya
# Processing Record 37 of Set 12 | powell
# Processing Record 38 of Set 12 | smithers
# Processing Record 39 of Set 12 | road town
# Processing Record 40 of Set 12 | flin flon
# Processing Record 41 of Set 12 | honiton
# Processing Record 42 of Set 12 | yerbogachen
# Processing Record 43 of Set 12 | hervey bay
# Processing Record 44 of Set 12 | dolbeau
# City not found. Skipping...
# Processing Record 45 of Set 12 | conde
# Processing Record 46 of Set 12 | bria
# Processing Record 47 of Set 12 | altamont
# Processing Record 48 of Set 12 | alugan
# Processing Record 49 of Set 12 | grenaa
# Processing Record 50 of Set 12 | ixcaquixtla
# City not found. Skipping...
# Processing Record 1 of Set 13 | portland
# Processing Record 2 of Set 13 | sola
# Processing Record 3 of Set 13 | bulacan
# Processing Record 4 of Set 13 | caravelas
# Processing Record 5 of Set 13 | tacoronte
# Processing Record 6 of Set 13 | tevaitoa
# Processing Record 7 of Set 13 | san juan
# Processing Record 8 of Set 13 | yazman
# Processing Record 9 of Set 13 | cintalapa
# Processing Record 10 of Set 13 | kansk
# Processing Record 11 of Set 13 | gvarv
# Processing Record 12 of Set 13 | kropotkin
# Processing Record 13 of Set 13 | gouyave
# Processing Record 14 of Set 13 | haibowan
# City not found. Skipping...
# Processing Record 15 of Set 13 | umzimvubu
# City not found. Skipping...
# Processing Record 16 of Set 13 | gornopravdinsk
# Processing Record 17 of Set 13 | olafsvik
# Processing Record 18 of Set 13 | ahuimanu
# Processing Record 19 of Set 13 | kuah
# Processing Record 20 of Set 13 | minas
# Processing Record 21 of Set 13 | onverwacht
# Processing Record 22 of Set 13 | vostok
# Processing Record 23 of Set 13 | kasulu
# Processing Record 24 of Set 13 | sinnamary
# Processing Record 25 of Set 13 | amboasary
# Processing Record 26 of Set 13 | budogoshch
# Processing Record 27 of Set 13 | takoradi
# Processing Record 28 of Set 13 | murdochville
# Processing Record 29 of Set 13 | atherton
# Processing Record 30 of Set 13 | qandala
# Processing Record 31 of Set 13 | klaksvik
# Processing Record 32 of Set 13 | taywarah
# Processing Record 33 of Set 13 | ust-kamchatsk
# City not found. Skipping...
# Processing Record 34 of Set 13 | berberati
# Processing Record 35 of Set 13 | soligalich
# Processing Record 36 of Set 13 | seoul
# Processing Record 37 of Set 13 | vuktyl
# Processing Record 38 of Set 13 | tuatapere
# Processing Record 39 of Set 13 | yunjinghong
# City not found. Skipping...
# Processing Record 40 of Set 13 | glubokiy
# Processing Record 41 of Set 13 | uwayl
# City not found. Skipping...
# Processing Record 42 of Set 13 | prado
# Processing Record 43 of Set 13 | halalo
# City not found. Skipping...
# Processing Record 44 of Set 13 | krasnoselkup
# Processing Record 45 of Set 13 | trinidad
# Processing Record 46 of Set 13 | mount gambier
# Processing Record 47 of Set 13 | lanxi
# Processing Record 48 of Set 13 | funtua
# Processing Record 49 of Set 13 | daru
# Processing Record 50 of Set 13 | colon
# Processing Record 1 of Set 14 | zapolyarnyy
# Processing Record 2 of Set 14 | vysokogornyy
# Processing Record 3 of Set 14 | concarneau
# Processing Record 4 of Set 14 | liyang
# Processing Record 5 of Set 14 | chadiza
# Processing Record 6 of Set 14 | mahibadhoo
# Processing Record 7 of Set 14 | zheleznodorozhnyy
# Processing Record 8 of Set 14 | yeovil
# Processing Record 9 of Set 14 | mount isa
# Processing Record 10 of Set 14 | alyangula
# Processing Record 11 of Set 14 | cabinda
# Processing Record 12 of Set 14 | kontagora
# Processing Record 13 of Set 14 | pirgos
# Processing Record 14 of Set 14 | kashi
# Processing Record 15 of Set 14 | moranbah
# Processing Record 16 of Set 14 | viedma
# Processing Record 17 of Set 14 | pundaguitan
# Processing Record 18 of Set 14 | chino valley
# Processing Record 19 of Set 14 | garhi khairo
# Processing Record 20 of Set 14 | qui nhon
# Processing Record 21 of Set 14 | lagunas
# Processing Record 22 of Set 14 | phan thiet
# Processing Record 23 of Set 14 | suratgarh
# Processing Record 24 of Set 14 | wad madani
# Processing Record 25 of Set 14 | itahari
# City not found. Skipping...
# Processing Record 26 of Set 14 | solnechnyy
# Processing Record 27 of Set 14 | sterling
# Processing Record 28 of Set 14 | thai binh
# Processing Record 29 of Set 14 | beruni
# City not found. Skipping...
# Processing Record 30 of Set 14 | kambove
# Processing Record 31 of Set 14 | marevo
# Processing Record 32 of Set 14 | ucluelet
# Processing Record 33 of Set 14 | bam
# Processing Record 34 of Set 14 | kincardine
# Processing Record 35 of Set 14 | prince rupert
# Processing Record 36 of Set 14 | tromso
# Processing Record 37 of Set 14 | olinda
# Processing Record 38 of Set 14 | katobu
# Processing Record 39 of Set 14 | tanete
# Processing Record 40 of Set 14 | byron bay
# Processing Record 41 of Set 14 | longlac
# City not found. Skipping...
# Processing Record 42 of Set 14 | el olivar
# Processing Record 43 of Set 14 | lazo
# Processing Record 44 of Set 14 | bokovskaya
# Processing Record 45 of Set 14 | lavrentiya
# Processing Record 46 of Set 14 | yatou
# Processing Record 47 of Set 14 | stephenville
# Processing Record 48 of Set 14 | sungairaya
# Processing Record 49 of Set 14 | xichang
# Processing Record 50 of Set 14 | krasnoarmeysk
# Processing Record 1 of Set 15 | kangaatsiaq
# Processing Record 2 of Set 15 | teguldet
# Processing Record 3 of Set 15 | beira
# Processing Record 4 of Set 15 | santiago de cao
# Processing Record 5 of Set 15 | dimona
# Processing Record 6 of Set 15 | kedrovyy
# Processing Record 7 of Set 15 | te anau
# Processing Record 8 of Set 15 | narasannapeta
# Processing Record 9 of Set 15 | adre
# Processing Record 10 of Set 15 | ust-tsilma
# Processing Record 11 of Set 15 | faro
# Processing Record 12 of Set 15 | quelimane
# Processing Record 13 of Set 15 | duzce
# Processing Record 14 of Set 15 | ganzhou
# Processing Record 15 of Set 15 | gajraula
# Processing Record 16 of Set 15 | melfi
# Processing Record 17 of Set 15 | kununurra
# Processing Record 18 of Set 15 | nanakuli
# Processing Record 19 of Set 15 | changping
# Processing Record 20 of Set 15 | huilong
# Processing Record 21 of Set 15 | ipojuca
# Processing Record 22 of Set 15 | antanifotsy
# Processing Record 23 of Set 15 | sobolevo
# Processing Record 24 of Set 15 | nishihara
# Processing Record 25 of Set 15 | kaliua
# Processing Record 26 of Set 15 | shouguang
# Processing Record 27 of Set 15 | knysna
# Processing Record 28 of Set 15 | ryotsu
# Processing Record 29 of Set 15 | amherst
# Processing Record 30 of Set 15 | temaraia
# City not found. Skipping...
# Processing Record 31 of Set 15 | thinadhoo
# Processing Record 32 of Set 15 | hearst
# Processing Record 33 of Set 15 | paamiut
# Processing Record 34 of Set 15 | cap malheureux
# Processing Record 35 of Set 15 | san antonio
# Processing Record 36 of Set 15 | edd
# Processing Record 37 of Set 15 | tamworth
# Processing Record 38 of Set 15 | samarai
# Processing Record 39 of Set 15 | satitoa
# City not found. Skipping...
# Processing Record 40 of Set 15 | loa janan
# Processing Record 41 of Set 15 | vanimo
# Processing Record 42 of Set 15 | hobyo
# Processing Record 43 of Set 15 | kirkenaer
# Processing Record 44 of Set 15 | bud
# Processing Record 45 of Set 15 | sampit
# Processing Record 46 of Set 15 | axim
# Processing Record 47 of Set 15 | filadelfia
# Processing Record 48 of Set 15 | san jose
# Processing Record 49 of Set 15 | virginia beach
# Processing Record 50 of Set 15 | tahta
# Processing Record 1 of Set 16 | marzuq
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Print the length of the city_data list to verify how many cities you have
len(city_data)
# Out:
# 691

# %% [markdown]
# ## Add the weather data to a new DataFrame.

# %%
# Use the city_data list to create a new pandas DataFrame.
city_data_df = # YOUR CODE HERE

# %%
# Display sample data
city_data_df.head(10)
# Out:
#               City      Lat       Lng  Max Temp Current Description  Humidity  \
# 0            Bluff -46.6000  168.3333     56.80          few clouds        68
# 1            Metro  -5.1131  105.3067     88.48     overcast clouds        54
# 2    Pacific Grove  36.6177 -121.9166     64.08           clear sky        87
# 3     Saint George  37.1041 -113.5841     79.95           clear sky        40
# 4          Mataura -46.1927  168.8643     56.48          few clouds        56
# 5          Biltine  14.5333   20.9167     80.42    scattered clouds        61
# 6              Gao  16.6362    1.6370     85.73       broken clouds        47
# 7        Hithadhoo  -0.6000   73.0833     82.00    scattered clouds        72
# 8  Bambous Virieux -20.3428   57.7575     76.21       broken clouds        78
# 9          Rikitea -23.1203 -134.9692     73.35           clear sky        72
#
#    Cloudiness  Wind Speed Country
# 0          21        2.28      NZ
# 1          92        4.52      ID
# 2           0        4.61      US
# 3           0       10.36      US
# 4          15        2.44      NZ
# 5          27        3.36      TD
# 6          77        6.31      ML
# 7          47        7.78      MV
# 8          75       13.80      MU
# 9           3       14.23      PF

# %%
# Display the DataFrame's column names using the columns Pandas function
city_data_df.columns
# Out:
# Index(['City', 'Lat', 'Lng', 'Max Temp', 'Current Description', 'Humidity',
#        'Cloudiness', 'Wind Speed', 'Country'],
#       dtype='object')

# %%
# Create a list to reorder the column names as follows:
# "City", "Country", "Lat", "Lng", "Max Temp", "Humidity",  "Cloudiness", "Wind Speed",  "Current Description"
# YOUR CODE HERE

# Recreate the DataFrame by using the new column order
# YOUR CODE HERE

# Display sample data
# YOUR CODE HERE
# Out:
#               City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0            Bluff      NZ -46.6000  168.3333     56.80        68          21
# 1            Metro      ID  -5.1131  105.3067     88.48        54          92
# 2    Pacific Grove      US  36.6177 -121.9166     64.08        87           0
# 3     Saint George      US  37.1041 -113.5841     79.95        40           0
# 4          Mataura      NZ -46.1927  168.8643     56.48        56          15
# 5          Biltine      TD  14.5333   20.9167     80.42        61          27
# 6              Gao      ML  16.6362    1.6370     85.73        47          77
# 7        Hithadhoo      MV  -0.6000   73.0833     82.00        72          47
# 8  Bambous Virieux      MU -20.3428   57.7575     76.21        78          75
# 9          Rikitea      PF -23.1203 -134.9692     73.35        72           3
#
#    Wind Speed Current Description
# 0        2.28          few clouds
# 1        4.52     overcast clouds
# 2        4.61           clear sky
# 3       10.36           clear sky
# 4        2.44          few clouds
# 5        3.36    scattered clouds
# 6        6.31       broken clouds
# 7        7.78    scattered clouds
# 8       13.80       broken clouds
# 9       14.23           clear sky

# %%
# Display the data types of each column by using the dtypes Pandas function
# YOUR CODE HERE
# Out:
# City                    object
# Country                 object
# Lat                    float64
# Lng                    float64
# Max Temp               float64
# Humidity                 int64
# Cloudiness               int64
# Wind Speed             float64
# Current Description     object
# dtype: object

# %% [markdown]
# ## Export the DataFrame as a CSV file, and save it as `WeatherPy_Database.csv` in the `Weather_Database` folder.

# %%
# Set the output file name
# YOUR CODE HERE

# Export the city_data DataFrame into a CSV file
# YOUR CODE HERE
